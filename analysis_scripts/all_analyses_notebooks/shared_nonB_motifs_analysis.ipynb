# %% [markdown]
# # Intersecting Haplotype Motif Annotations with CHM13
# We use the CHM13 reference genome Non-B Annotations and intersect ALL Haplotypes with the reference to understand which Motifs are shared by Haplotypes

# %%
import pandas as pd

def process_intersections(bed_file):
    # Read BED file into a DataFrame
    df = pd.read_csv(bed_file, sep='\t', header=None, names=['chrom', 'start', 'end', 'stability1', 'filename', 'chrom2', 'start2', 'end2', 'stability2'])
    
    # Drop duplicate filenames for the same region, considering only the relevant columns
    df_unique = df.drop_duplicates(subset=['chrom', 'start', 'end', 'filename'])
    
    # Group by chrom, start, and end columns and count unique filenames
    grouped = df_unique.groupby(['chrom', 'start', 'end'])['filename'].nunique().reset_index(name='unique_haplotype_count')
    
    # Sort the grouped DataFrame by unique_haplotype_count in descending order
    sorted_grouped = grouped.sort_values(by='unique_haplotype_count', ascending=False)
    
    return sorted_grouped

# Main script
bed_file_path = '/home/alextu/scratch/results/bed_files/chm13/quadron_haplotype_intersections_chm13_query/verkko_batch123_chm13_quadron_posstrand_intersected_output.bed'
grouped_intersections = process_intersections(bed_file_path)

# Print the top 10 most shared G-quadruplex regions
print("Top 10 Most Shared Positive G-Quadruplex Regions:")
print(grouped_intersections.head(10))
# Out:
# Top 10 Most Shared Positive G-Quadruplex Regions:
#        chrom      start        end  unique_haplotype_count
# 22539  chr12  133005163  133011865                      49
# 89108   chr8  144820876  144824591                      47
# 13132  chr11     692395     693434                      43
# 58316  chr20     321487     322359                      42
# 22297  chr12  131961785  131964685                      38
# 71594   chr4    1018653    1019280                      36
# 8916   chr10     511390     512817                      34
# 35183  chr17     941125     942260                      34
# 21705  chr12  121740473  121744476                      31
# 13510  chr11    1465130    1466290                      31

# %%
import pandas as pd

def extract_sample_name(filename):
    """Extract the first part of the filename before the first underscore."""
    return filename.split('_')[0]

def process_intersections(bed_file, metadata_file):
    """Process BED file and merge it with metadata to find ancestry-specific regions."""
    # Read the BED file into a DataFrame
    df = pd.read_csv(bed_file, sep='\t', header=None, 
                     names=['chrom', 'start', 'end', 'score', 'filename', 'chrom2', 'start2', 'end2', 'score2'])
    
    # Drop duplicate filenames for the same region
    df_unique = df.drop_duplicates(subset=['chrom', 'start', 'end', 'filename']).copy()
    
    # Extract sample name from filename
    df_unique['Sample'] = df_unique['filename'].apply(extract_sample_name)
    
    # Read the metadata file into a DataFrame
    metadata_df = pd.read_csv(metadata_file, delimiter='\t')
    
    # Merge metadata with the DataFrame
    df_merged = pd.merge(df_unique, 
                         metadata_df[['Sample name', 'Sex', 'Superpopulation name', 'Superpopulation code']],
                         left_on='Sample', right_on='Sample name', how='left')
    
    # Group by the chrom, start, and end columns and aggregate unique filenames and metadata
    grouped = df_merged.groupby(['chrom', 'start', 'end']).agg(
        unique_haplotype_count=('filename', 'nunique'),
        haplotypes=('filename', lambda x: list(x)),
        superpopulations=('Superpopulation name', lambda x: list(x)),
        superpopulation_codes=('Superpopulation code', lambda x: list(x)),
        unique_sample_count=('Sample', 'nunique')
    ).reset_index()
    
    return grouped

def find_shared_regions(grouped_intersections):
    """Identify regions shared by 5 or more haplotypes of the same ancestry."""
    shared_regions = grouped_intersections[
        (grouped_intersections['superpopulations'].apply(lambda x: len(set(x)) == 1)) & 
        (grouped_intersections['unique_sample_count'] >= 5)
    ]
    return shared_regions

# Main
bed_file_path = '/home/alextu/scratch/results/bed_files/chm13/quadron_haplotype_intersections_chm13_query/verkko_batch123_chm13_quadron_posstrand_intersected_output.bed'
metadata_file_path = '/home/alextu/scratch/igsr_sample_metadata/igsr_samples.tsv'

# Process intersections
grouped_intersections = process_intersections(bed_file_path, metadata_file_path)

# Find regions shared by 5 or more haplotypes of the same ancestry
shared_regions = find_shared_regions(grouped_intersections)

# Print the shared regions
print(shared_regions)
# Out:
#        chrom      start        end  unique_haplotype_count  \
# 93      chr1     469936     470018                       9
# 114     chr1     486907     486944                       6
# 140     chr1     520317     520447                       5
# 160     chr1     565868     565926                       5
# 165     chr1     567815     567861                       5
# 1335    chr1    5954780    5954834                       5
# 1352    chr1    5996534    5996559                       5
# 8879   chr10      34292      34337                       5
# 13227  chr11     889737     889788                       5
# 13842  chr11    2185143    2185175                       5
# 18724  chr11  132753385  132753412                       5
# 18746  chr11  133367485  133367514                       5
# 26188  chr14   95998057   95998119                       5
# 30169  chr16     988458     988576                       5
# 35165  chr17     865467     865689                       5
# 35210  chr17    1069220    1069282                       5
# 35812  chr17    4750240    4750269                       5
# 38078  chr17   41083456   41083580                       5
# 38465  chr17   44699821   44699850                       6
# 39748  chr17   66358140   66358465                       5
# 41178  chr17   81563970   81564002                       5
# 41703  chr17   83255944   83255985                       5
# 43256  chr19     417865     417884                       5
# 44055  chr19    1735672    1735729                       5
# 44273  chr19    2313065    2313104                       5
# 45392  chr19    6185555    6185572                       6
# 46625  chr19   13721617   13721668                       5
# 47694  chr19   19067936   19068035                       5
# 47786  chr19   19624891   19624944                       5
# 51011  chr19   52894666   52894707                       5
# 51070  chr19   53313329   53313384                       6
# 56845   chr2  218277148  218277174                       5
# 58423  chr20    1006128    1006173                       5
# 58494  chr20    1862302    1862338                       5
# 58676  chr20    4114523    4114637                       5
# 71794   chr4    1613126    1613150                       5
# 78610   chr6   33505369   33505425                       5
# 81170   chr7    1270900    1270925                       6
# 81238   chr7    1386485    1386510                       5
# 85986   chr8    1272322    1272363                       6
# 86099   chr8    2186250    2186281                       6
# 88987   chr8  144519924  144519973                       5
# 89244   chr8  145179779  145179807                       5
#
#                                               haplotypes  \
# 93     [HG02587_hap2_quadron_filtered_verkko_batch1_p...
# 114    [HG02953_hap1_quadron_filtered_verkko_batch1_p...
# 140    [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 160    [HG02953_hap2_quadron_filtered_verkko_batch1_p...
# 165    [HG02953_hap2_quadron_filtered_verkko_batch1_p...
# 1335   [HG02554_hap2_quadron_filtered_verkko_batch1_p...
# 1352   [HG02282_hap1_quadron_filtered_verkko_batch1_p...
# 8879   [HG02554_hap2_quadron_filtered_verkko_batch1_p...
# 13227  [HG03065_hap1_quadron_filtered_verkko_batch2_p...
# 13842  [HG02587_hap2_quadron_filtered_verkko_batch1_p...
# 18724  [HG02282_hap1_quadron_filtered_verkko_batch1_p...
# 18746  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 26188  [HG02587_hap2_quadron_filtered_verkko_batch1_p...
# 30169  [HG02282_hap2_quadron_filtered_verkko_batch1_p...
# 35165  [HG02554_hap1_quadron_filtered_verkko_batch1_p...
# 35210  [HG02666_hap2_quadron_filtered_verkko_batch1_p...
# 35812  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 38078  [HG02666_hap1_quadron_filtered_verkko_batch1_p...
# 38465  [HG02282_hap2_quadron_filtered_verkko_batch1_p...
# 39748  [HG02554_hap1_quadron_filtered_verkko_batch1_p...
# 41178  [HG02011_hap1_quadron_filtered_verkko_batch2_p...
# 41703  [HG02666_hap1_quadron_filtered_verkko_batch1_p...
# 43256  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 44055  [HG02282_hap2_quadron_filtered_verkko_batch1_p...
# 44273  [HG02554_hap2_quadron_filtered_verkko_batch1_p...
# 45392  [HG02011_hap1_quadron_filtered_verkko_batch2_p...
# 46625  [HG03452_hap1_quadron_filtered_verkko_batch1_p...
# 47694  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 47786  [HG02282_hap2_quadron_filtered_verkko_batch1_p...
# 51011  [HG02587_hap2_quadron_filtered_verkko_batch1_p...
# 51070  [HG02282_hap1_quadron_filtered_verkko_batch1_p...
# 56845  [HG01890_hap1_quadron_filtered_verkko_batch2_p...
# 58423  [HG02011_hap2_quadron_filtered_verkko_batch2_p...
# 58494  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 58676  [HG03520_hap2_quadron_filtered_verkko_batch1_p...
# 71794  [HG03371_hap1_quadron_filtered_verkko_batch2_p...
# 78610  [HG02587_hap1_quadron_filtered_verkko_batch1_p...
# 81170  [HG02011_hap1_quadron_filtered_verkko_batch2_p...
# 81238  [HG01890_hap2_quadron_filtered_verkko_batch2_p...
# 85986  [HG02011_hap1_quadron_filtered_verkko_batch2_p...
# 86099  [HG02666_hap2_quadron_filtered_verkko_batch1_p...
# 88987  [HG02666_hap2_quadron_filtered_verkko_batch1_p...
# 89244  [HG02011_hap2_quadron_filtered_verkko_batch2_p...
#
#                                         superpopulations  \
# 93     [African Ancestry, African Ancestry, African A...
# 114    [African Ancestry, African Ancestry, African A...
# 140    [African Ancestry, African Ancestry, African A...
# 160    [African Ancestry, African Ancestry, African A...
# 165    [African Ancestry, African Ancestry, African A...
# 1335   [African Ancestry, African Ancestry, African A...
# 1352   [African Ancestry, African Ancestry, African A...
# 8879   [African Ancestry, African Ancestry, African A...
# 13227  [African Ancestry, African Ancestry, African A...
# 13842  [African Ancestry, African Ancestry, African A...
# 18724  [African Ancestry, African Ancestry, African A...
# 18746  [African Ancestry, African Ancestry, African A...
# 26188  [African Ancestry, African Ancestry, African A...
# 30169  [African Ancestry, African Ancestry, African A...
# 35165  [African Ancestry, African Ancestry, African A...
# 35210  [African Ancestry, African Ancestry, African A...
# 35812  [African Ancestry, African Ancestry, African A...
# 38078  [African Ancestry, African Ancestry, African A...
# 38465  [African Ancestry, African Ancestry, African A...
# 39748  [African Ancestry, African Ancestry, African A...
# 41178  [African Ancestry, African Ancestry, African A...
# 41703  [African Ancestry, African Ancestry, African A...
# 43256  [African Ancestry, African Ancestry, African A...
# 44055  [African Ancestry, African Ancestry, African A...
# 44273  [African Ancestry, African Ancestry, African A...
# 45392  [African Ancestry, African Ancestry, African A...
# 46625  [African Ancestry, African Ancestry, African A...
# 47694  [African Ancestry, African Ancestry, African A...
# 47786  [African Ancestry, African Ancestry, African A...
# 51011  [African Ancestry, African Ancestry, African A...
# 51070  [African Ancestry, African Ancestry, African A...
# 56845  [African Ancestry, African Ancestry, African A...
# 58423  [African Ancestry, African Ancestry, African A...
# 58494  [African Ancestry, African Ancestry, African A...
# 58676  [African Ancestry, African Ancestry, African A...
# 71794  [African Ancestry, African Ancestry, African A...
# 78610  [African Ancestry, African Ancestry, African A...
# 81170  [African Ancestry, African Ancestry, African A...
# 81238  [African Ancestry, African Ancestry, African A...
# 85986  [African Ancestry, African Ancestry, African A...
# 86099  [African Ancestry, African Ancestry, African A...
# 88987  [African Ancestry, African Ancestry, African A...
# 89244  [African Ancestry, African Ancestry, African A...
#
#                                superpopulation_codes  unique_sample_count
# 93     [AFR, AFR, AFR, AFR, AFR, AFR, AFR, AFR, AFR]                    7
# 114                   [AFR, AFR, AFR, AFR, AFR, AFR]                    5
# 140                        [AFR, AFR, AFR, AFR, AFR]                    5
# 160                        [AFR, AFR, AFR, AFR, AFR]                    5
# 165                        [AFR, AFR, AFR, AFR, AFR]                    5
# 1335                       [AFR, AFR, AFR, AFR, AFR]                    5
# 1352                       [AFR, AFR, AFR, AFR, AFR]                    5
# 8879                       [AFR, AFR, AFR, AFR, AFR]                    5
# 13227                      [AFR, AFR, AFR, AFR, AFR]                    5
# 13842                      [AFR, AFR, AFR, AFR, AFR]                    5
# 18724                      [AFR, AFR, AFR, AFR, AFR]                    5
# 18746                      [AFR, AFR, AFR, AFR, AFR]                    5
# 26188                      [AFR, AFR, AFR, AFR, AFR]                    5
# 30169                      [AFR, AFR, AFR, AFR, AFR]                    5
# 35165                      [AFR, AFR, AFR, AFR, AFR]                    5
# 35210                      [AFR, AFR, AFR, AFR, AFR]                    5
# 35812                      [AFR, AFR, AFR, AFR, AFR]                    5
# 38078                      [AFR, AFR, AFR, AFR, AFR]                    5
# 38465                 [AFR, AFR, AFR, AFR, AFR, AFR]                    6
# 39748                      [AFR, AFR, AFR, AFR, AFR]                    5
# 41178                      [AFR, AFR, AFR, AFR, AFR]                    5
# 41703                      [AFR, AFR, AFR, AFR, AFR]                    5
# 43256                      [AFR, AFR, AFR, AFR, AFR]                    5
# 44055                      [AFR, AFR, AFR, AFR, AFR]                    5
# 44273                      [AFR, AFR, AFR, AFR, AFR]                    5
# 45392                 [AFR, AFR, AFR, AFR, AFR, AFR]                    5
# 46625                      [AFR, AFR, AFR, AFR, AFR]                    5
# 47694                      [AFR, AFR, AFR, AFR, AFR]                    5
# 47786                      [AFR, AFR, AFR, AFR, AFR]                    5
# 51011                      [AFR, AFR, AFR, AFR, AFR]                    5
# 51070                 [AFR, AFR, AFR, AFR, AFR, AFR]                    6
# 56845                      [AFR, AFR, AFR, AFR, AFR]                    5
# 58423                      [AFR, AFR, AFR, AFR, AFR]                    5
# 58494                      [AFR, AFR, AFR, AFR, AFR]                    5
# 58676                      [AFR, AFR, AFR, AFR, AFR]                    5
# 71794                      [AFR, AFR, AFR, AFR, AFR]                    5
# 78610                      [AFR, AFR, AFR, AFR, AFR]                    5
# 81170                 [AFR, AFR, AFR, AFR, AFR, AFR]                    6
# 81238                      [AFR, AFR, AFR, AFR, AFR]                    5
# 85986                 [AFR, AFR, AFR, AFR, AFR, AFR]                    5
# 86099                 [AFR, AFR, AFR, AFR, AFR, AFR]                    6
# 88987                      [AFR, AFR, AFR, AFR, AFR]                    5
# 89244                      [AFR, AFR, AFR, AFR, AFR]                    5
